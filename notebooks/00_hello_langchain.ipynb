# %% [markdown]
# # Hello LangChain
#
# Smoke-test notebook. Ověří, že kernel startuje a LangChain + LangSmith se naimportují.

# %%
from kosik_workshop.config import load_env

load_env()

# %%
import langchain
import langsmith

print("langchain", langchain.__version__)
print("langsmith", langsmith.__version__)
# Out:
# langchain 1.2.15
# langsmith 0.7.33
